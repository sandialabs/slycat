# %% [markdown]
# # Overview
#
# This notebook demonstrates using the Slycat CCA algorithm with data containing constant columns.
#
# **Note: Assumes that your PYTHONPATH includes the Slycat package directory.**

# %%
import numpy
import toyplot.color

# %% [markdown]
# First, we load row-oriented data from a CSV file, transforming it into a dictionary mapping column names to numpy-array columns:

# %%
rows = [row.split(",") for row in open("../data/cars.csv")]
columns = zip(*rows)
columns = {column[0].strip() : numpy.array(column[1:], dtype="float64" if column[0].strip() not in ["Model"] else "string") for column in columns}
print sorted(columns.keys())
# Out:
# ['Acceleration', 'Cylinders', 'Displacement', 'Horsepower', 'MPG', 'Model', 'Origin', 'Weight', 'Year']

# %% [markdown]
# Next, we add some columns containing constant values:

# %%
columns["k1"] = numpy.arange(len(columns["Year"]))
columns["k2"] = 1 + numpy.arange(len(columns["Year"]))
print sorted(columns.keys())
# Out:
# ['Acceleration', 'Cylinders', 'Displacement', 'Horsepower', 'MPG', 'Model', 'Origin', 'Weight', 'Year', 'k1', 'k2']

# %% [markdown]
# Next, we extract the columns to be used as inputs and outputs, converting them into numpy matrices:

# %%
inputs = numpy.column_stack([columns[name] for name in ["Cylinders", "Displacement", "Weight", "Year", "k1"]])
outputs = numpy.column_stack([columns[name] for name in ["Acceleration", "Horsepower", "MPG", "k2"]])

# %% [markdown]
# This dataset contains NaN (null) values, so we create a numpy array that identifies all of the "good" rows (rows that don't contain a NaN in any of the input or output columns):

# %%
good_rows = ~numpy.isnan(numpy.column_stack((inputs, outputs))).any(axis=1)

# %% [markdown]
# We extract the good rows from the input and output matrices to act as the inputs to the CCA algorithm:

# %%
X = inputs[good_rows]
Y = outputs[good_rows]

# %% [markdown]
# Finally, we compute the CCA and generate a scatterplot from the results:

# %%
from slycat.cca import cca

x, y, x_loadings, y_loadings, r, wilks = cca(X, Y, scale_inputs=False, force_positive=True)

print "r^2:\n%s\n" % r
print "x loadings:\n%s\n" % x_loadings
print "y loadings:\n%s\n" % y_loadings
# Out:
# r^2:
# [ 1.          0.93444342  0.4611226   0.10929471]
#
# x loadings:
# [[  3.61502796e-01   8.44134834e-01   1.59506983e-01  -2.30849736e-01]
#  [  3.88541710e-01   8.82993836e-01   2.25505950e-01   3.37092710e-02]
#  [  3.22363044e-01   9.36800790e-01  -1.21962510e-01   2.45330666e-02]
#  [ -9.96677116e-01   7.92179053e-03   2.97968125e-04   4.62510213e-02]
#  [ -1.00000000e+00  -7.10089872e-16  -1.00584222e-15   1.73460413e-15]]
#
# y loadings:
# [[ -2.93013035e-01  -4.20923027e-01  -8.05315639e-01   2.97378358e-01]
#  [  4.24621234e-01   8.49869540e-01   2.94877156e-01   1.02303646e-01]
#  [ -5.86234854e-01  -7.24091446e-01   1.82188350e-01   3.14368700e-01]
#  [ -1.00000000e+00  -2.57381919e-16   2.89909941e-16   1.92641682e-16]]

# %%
colormap = toyplot.color.diverging("BlueRed")

canvas = toyplot.Canvas(1000, 300)
axes = canvas.axes(grid=(1, 3, 0), label="1st CCA Component")
axes.scatterplot(x.T[0], y.T[0], fill=columns["MPG"][good_rows], fill_colormap=colormap)

axes = canvas.axes(grid=(1, 3, 1), label="2nd CCA Component")
axes.scatterplot(x.T[1], y.T[1], fill=columns["MPG"][good_rows], fill_colormap=colormap)

axes = canvas.axes(grid=(1, 3, 2), label="3rd CCA Component")
axes.scatterplot(x.T[2], y.T[2], fill=columns["MPG"][good_rows], fill_colormap=colormap)
axes.colorbar(columns["MPG"][good_rows], label="MPG", colormap=colormap)
# Out:
# <div align="center" class="toyplot" id="t024f34e5d75f4ee8b8891d958dd825dd"><svg height="300px" id="t4580ea8ea53b461e90e1f9ca6e63f6ab" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="1000px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t89ac78036a394e35a72967912281b990"><toyplot:axes>{"y": [{"range": {"max": 240.0, "min": 60.0}, "scale": "linear", "domain": {"max": 2.0, "min": -2.0}}], "x": [{"range": {"max": 273.3333333333333, "min": 60.0}, "scale": "linear", "domain": {"max": 2.0, "min": -2.0}}]}</toyplot:axes><clipPath id="t868da5bde55a41eba6c4a24ef58174bd"><rect height="200.0" width="233.333333333" x="50.0" y="50.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t868da5bde55a41eba6c4a24ef58174bd)" style="cursor:crosshair;"><rect height="200.0" style="pointer-events:all;visibility:hidden;" width="233.333333333" x="50.0" y="50.0"></rect><g class="toyplot-PlotMark" id="tf85a99424eb849bfa01cafc09d8304c1" style="stroke:none;fill:none;"><toyplot:data-table title="Plot Data">{"data": [[1.7763535846887628, 1.7676644408968287, 1.758975297104895, 1.7502861533129612, 1.7415970095210274, 1.732907865729093, 1.7242187219371592, 1.7155295781452253, 1.7068404343532915, 1.6981512905613578, 1.6460164278097547, 1.6373272840178208, 1.6199489964339533, 1.6112598526420194, 1.602570708850086, 1.593881565058152, 1.585192421266218, 1.5765032774742842, 1.5678141336823506, 1.5591249898904167, 1.5504358460984826, 1.541746702306549, 1.5330575585146151, 1.5243684147226813, 1.5156792709307472, 1.506990127138813, 1.4983009833468792, 1.4896118395549454, 1.4809226957630115, 1.4722335519710783, 1.4635444081791442, 1.4548552643872104, 1.4287878330114088, 1.4200986892194747, 1.4114095454275408, 1.402720401635607, 1.394031257843673, 1.3853421140517392, 1.3766529702598052, 1.3679638264678715, 1.3592746826759377, 1.3505855388840036, 1.3418963950920697, 1.3332072513001358, 1.3245181075082022, 1.3158289637162686, 1.3071398199243345, 1.2984506761324006, 1.289761532340467, 1.2810723885485331, 1.2723832447565995, 1.2636941009646656, 1.255004957172732, 1.246315813380798, 1.2376266695888642, 1.2289375257969304, 1.2202483820049965, 1.2115592382130627, 1.2028700944211288, 1.194180950629195, 1.185491806837261, 1.1768026630453268, 1.168113519253393, 1.1594243754614593, 1.1507352316695252, 1.1420460878775915, 1.1333569440856572, 1.1246678002937236, 1.1159786565017897, 1.1072895127098559, 1.0986003689179225, 1.0899112251259884, 1.0812220813340545, 1.0725329375421206, 1.0638437937501868, 1.0551546499582531, 1.0464655061663193, 1.0377763623743854, 1.0290872185824516, 1.0203980747905177, 1.0117089309985838, 1.00301978720665, 0.9943306434147161, 0.9856414996227822, 0.9769523558308483, 0.9682632120389145, 0.9595740682469805, 0.9508849244550468, 0.9421957806631129, 0.9335066368711786, 0.924817493079245, 0.9161283492873112, 0.9074392054953774, 0.8987500617034433, 0.8900609179115093, 0.8813717741195758, 0.8726826303276422, 0.8639934865357082, 0.8553043427437744, 0.8466151989518405, 0.8379260551599068, 0.8292369113679731, 0.8205477675760385, 0.8118586237841047, 0.8031694799921709, 0.7944803362002372, 0.7857911924083036, 0.77710204861637, 0.768412904824436, 0.7597237610325022, 0.7510346172405683, 0.7423454734486344, 0.7336563296567007, 0.7249671858647668, 0.7162780420728325, 0.7075888982808985, 0.6988997544889654, 0.6902106106970313, 0.6815214669050974, 0.6728323231131634, 0.6641431793212295, 0.6554540355292958, 0.646764891737362, 0.6380757479454278, 0.6293866041534943, 0.6120083165696265, 0.6033191727776926, 0.5946300289857592, 0.5859408851938251, 0.5772517414018915, 0.5685625976099574, 0.5598734538180233, 0.5511843100260895, 0.5424951662341557, 0.5338060224422218, 0.5251168786502878, 0.5164277348583539, 0.50773859106642, 0.4990494472744863, 0.4903603034825528, 0.48167115 ...
