# %% [markdown]
# # Overview
#
# This notebook demonstrates using the Slycat CCA algorithm.
#
# **Note: Assumes that your PYTHONPATH includes the Slycat package directory.**

# %%
import numpy
import toyplot.color

# %% [markdown]
# First, we load row-oriented data from a CSV file, transforming it into a dictionary mapping column names to numpy-array columns:

# %%
rows = [row.split(",") for row in open("../data/cars.csv")]
columns = zip(*rows)
columns = {column[0].strip() : numpy.array(column[1:], dtype="float64" if column[0].strip() not in ["Model"] else "string") for column in columns}
print sorted(columns.keys())
# Out:
# ['Acceleration', 'Cylinders', 'Displacement', 'Horsepower', 'MPG', 'Model', 'Origin', 'Weight', 'Year']

# %% [markdown]
# Next, we extract the columns to be used as inputs and outputs, converting them into numpy matrices:

# %%
inputs = numpy.column_stack([columns[name] for name in ["Cylinders", "Displacement", "Weight", "Year"]])
outputs = numpy.column_stack([columns[name] for name in ["Acceleration", "Horsepower", "MPG"]])

# %% [markdown]
# This dataset contains NaN (null) values, so we create a numpy array that identifies all of the "good" rows (rows that don't contain a NaN in any of the input or output columns):

# %%
good_rows = ~numpy.isnan(numpy.column_stack((inputs, outputs))).any(axis=1)

# %% [markdown]
# We extract the good rows from the input and output matrices to act as the inputs to the CCA algorithm:

# %%
X = inputs[good_rows]
Y = outputs[good_rows]

# %% [markdown]
# Finally, we compute the CCA and generate a scatterplot from the results:

# %%
from slycat.cca import cca

x, y, x_loadings, y_loadings, r, wilks = cca(X, Y, scale_inputs=True, force_positive=True)

print "x:\n%s\n" % x
print "y:\n%s\n" % y
print "x loadings:\n%s\n" % x_loadings
print "y loadings:\n%s\n" % y_loadings
print "r^2:\n%s\n" % r
print "wilks:\n%s\n" % wilks
# Out:
# x:
# [[ 1.04338114  0.20432395 -1.86365563]
#  [ 1.31183635  0.96383136 -1.71817802]
#  [ 1.02219832  0.70408887 -2.03867151]
#  ...,
#  [-1.04563573  1.47155596  0.93695757]
#  [-0.8335019   0.16710195  1.60842307]
#  [-0.76298099 -0.11152218  1.78634621]]
#
# y:
# [[ 0.56574165  0.50467047 -1.2312652 ]
#  [ 1.34630292  0.92959679 -0.28738048]
#  [ 0.86586041  1.1585421  -0.79205812]
#  ...,
#  [-1.12204536  1.68335121 -1.60111942]
#  [-0.54164991 -0.53331729  0.88856873]
#  [-0.61567761 -0.18938602  1.80306186]]
#
# x loadings:
# [[ 0.90584234  0.21692691 -0.0078397 ]
#  [ 0.95198913  0.29656589  0.03550055]
#  [ 0.96403782  0.00501307  0.25654017]
#  [-0.53568901  0.33804374  0.74795842]]
#
# y loadings:
# [[-0.50526195 -0.67963812  0.53179167]
#  [ 0.93932732  0.3414454   0.0328515 ]
#  [-0.93292801  0.2630621   0.24585294]]
#
# r^2:
# [ 0.95058154  0.46227843  0.35005168]
#
# wilks:
# [ 0.06650742  0.68994862  0.87746382]

# %%
palette = toyplot.color.brewer("RdYlBu", reverse=True)

canvas = toyplot.Canvas(900, 300)
axes = canvas.axes(grid=(1, 3, 0), gutter = 30, label="1st CCA Component")
axes.scatterplot(x.T[0], y.T[0], fill=columns["MPG"][good_rows], fill_palette=palette)

axes = canvas.axes(grid=(1, 3, 1), gutter = 30, label="2nd CCA Component")
axes.scatterplot(x.T[1], y.T[1], fill=columns["MPG"][good_rows], fill_palette=palette)

axes = canvas.axes(grid=(1, 3, 2), gutter = 30, label="3rd CCA Component")
axes.scatterplot(x.T[2], y.T[2], fill=columns["MPG"][good_rows], fill_palette=palette)
axes.colorbar(columns["MPG"][good_rows], label="MPG", palette=palette)
# Out:
# <div align="center" class="toyplot" id="t27fd485bc2674a22b432f3a8011bc466"><svg height="300px" id="t8e1ec86c74364b8d974cd3079ed94c67" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="900px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot