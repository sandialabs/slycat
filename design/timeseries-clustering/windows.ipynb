# %%
import numpy
import toyplot

# %%
windows = [
    ("Bartlett", numpy.bartlett(1000)),
    ("Blackman", numpy.blackman(1000)),
    ("Hamming", numpy.hamming(1000)),
    ("Hanning", numpy.hanning(1000)),
    ("Kaiser 0", numpy.kaiser(1000, beta=0)),
    ("Kaiser 1", numpy.kaiser(1000, beta=1)),
    ("Kaiser 5", numpy.kaiser(1000, beta=5)),
    ("Kaiser 10", numpy.kaiser(1000, beta=10)),
    ("Kaiser 15", numpy.kaiser(1000, beta=15)),
    ]

# %%
canvas = toyplot.Canvas()
for index, (label, window) in enumerate(windows):
    axes = canvas.axes(grid=(3, 3, index), gutter=40, ylabel=label)
    axes.plot(window)
# Out:
# <div align="center" class="toyplot" id="t1539d764f6d842718802727516a517ae"><svg height="600px" id="tada52106afaa4c5584cae5a10946a616" style="background-color:transparent;fill:#292724;fill-opacity:1.0;font-family:helvetica;font-size:12px;opacity:1.0;stroke:#292724;stroke-opacity:1.0;stroke-width:1.0" width="600px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-axes-Cartesian" id="t2e121854da8e4cb8a09ad027bcf9569a"><toyplot:axes>{"x": [{"domain": {"max": 1000.0, "min": 0}, "range": {"max": 150.0, "min": 50.0}, "scale": "linear"}], "y": [{"domain": {"max": 1.0, "min": 0.0}, "range": {"max": 150.0, "min": 50.0}, "scale": "linear"}]}</toyplot:axes><clipPath id="td7e42ccf70514040a8571c8f0607ca87"><rect height="120.0" width="120.0" x="40.0" y="40.0"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#td7e42ccf70514040a8571c8f0607ca87)" style="cursor:crosshair"><rect height="120.0" style="pointer-events:all;visibility:hid
# ...
