# %%
from __future__ import division

# %%
import numpy.fft
import scipy.signal
import scipy.spatial.distance
import toyplot

# %% [markdown]
# # Data Synthesis
#
# We begin by synthesizing our test data - in this case, a collection of sin waves with identical frequencies and varying phase:

# %%
t = numpy.linspace(0, 1, 1000)
n = len(t)
numpy.random.seed(12)
timeseries = numpy.row_stack([numpy.sin(t * 2 * numpy.pi * 10 + numpy.random.uniform(0, 2 * numpy.pi)) for i in range(20)])

# %%
canvas = toyplot.Canvas(1000, 1000)
axes = canvas.axes(xlabel="Time")
axes.y(show=False)
for index, y in enumerate(timeseries):
    axes.plot(t, (index*3) + y, style={"stroke":"#343434"})
# Out:
# <div align="center" class="toyplot" id="t6f2a9585509b4885ad69cc5cb4e40dfd"><svg height="1000px" id="t63784b95c9554e90934e89547bf036a4" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="1000px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t3a9d3aa0a2194df298f2284d2fe3b36c"><toyplot:axes>{"y": [{"range": {"max": 940, "min": 60}, "scale": "linear", "domain": {"max": 60.0, "min": -0.99999884817372853}}], "x": [{"range": {"max": 940, "min": 60}, "scale": "linear", "domain": {"max": 1.0, "min": 0.0}}]}</toyplot:axes><clipPath id="t0d9e283cb28547fabb9885a0ee198af9"><rect height="900" width="900" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t0d9e283cb28547fabb9885a0ee198af9)" style="cursor:crosshair;"><rect height="900" style="pointer-events:all;visibility:hidden;" width="900" x="50" y="50"></rect><polyline class="toyplot-PolyLineMark" id="t34cae21467bc46dcb3fce3a8e204adf5" points="60.0,913.684949415 60.8808808809,913.194857411 61.7617617618,912.753717208 62.6426426426,912.363273272 63.5235235235,912.025069591 64.4044044044,911.740443574 65.2852852853,911.510520759 66.1661661662,911.336210362 67.047047047,911.218201686 67.9279279279,911.156961388 68.8088088088,911.152731641 69.6896896897,911.20552917 70.5705705706,911.315145191 71.4514514515,911.481146232 72.3323323323,911.702875853 73.2132132132,911.979457235 74.0940940941,912.309796652 74.974974975,912.692587795 75.8558558559,913.126316937 76.7367367367,913.60926892 77.6176176176,914.139533938 78.4984984985,914.715015085 79.3793793794,915.333436652 80.2602602603,915.992353127 81.1411411411,916.689158858 82.022022022,917.421098366 82.9029029029,918.185277237 83.7837837838,918.978673566 84.6646646647,919.798149911 85.5455455455,920.640465697 86.4264264264,921.502290032 87.3073073073,922.38021488 88.1881881882,923.270768534 89.0690690691,924.170429348 89.9499499499,925.075639662 90.8308308308,925.982819873 91.7117117117,926.888382585 92.5925925926,927.7887468 93.4734734735,928.680352076 94.3543543544,929.559672609 95.2352352352,930.423231174 96.1161161161,931.267612876 96.996996997,932.089478654 97.8778778779,932.885578483 98.7587587588,933.652764231 99.6396396396,934.388002104 100.520520521,935.088384642 101.401401401,935.751142223 102.282282282,936.373654006 103.163163163,936.953458303 104.044044044,937.48826231 104.924924925,937.975951174 105.805805806,938.414596354 106.686686687,938.802463254 107.567567568,939.138018074 108.448448448,939.419933881 109.329329329,939.647095854 110.21021021,939.818605694 111.091091091,939.933785175 111.971971972,939.992178825 112.852852853,939.99355573 113.733733734,939.937910445 114.614614615,939.825463017 115.495495495,939.656658112 116.376376376,939.43216326 117.257257257,939.152866215 118.138138138,938.81987144 119.019019019,938.434495746 119.8998999,937.99826308 120.780780781,937.5128985 121.661661662,936.980321353 122.542542543,936.402637688 123.423423423,935.782131923 124.304304304,935.121257813 125.185185185,934.42262875 126.066066066,933.689007424 126.946946947,932.923294901 127.827827828,932.128519149 128.708708709,931.307823065 129.58958959,930.464452048 130.47047047,929.601741161 131.351351351,928.723101949 132.232232232,927.832008942 133.113113113,926.931985919 133.993993994,926.026591972 134.874874875,925.119407431 135.755755756,924.214019709 136.636636637,923.314009112 137.517517518,922.422934682 138.398398398,921.544320126 139.279279279,920.681639876 140.16016016,919.838305355 141.041041041,919.017651482 141.921921922,918.22292349 142.802802803,917.457264085 143.683683684,916.723701027 144.564564565,916.025135151 145.445445445,915.364328898 146.326326326,914.743895389 147.207207207,914.166288096 148.088088088,913.633791134 148.968968969,913.148510235 149.84984985,912.712364414 150.730730731,912.327078387 151. ...

# %% [markdown]
# # K-Means (Euclidean) Clustering on the Raw Timeseries
#
# First, we treat the timeseries values as features, and perform K-Means clustering.

# %%
features = timeseries

# %%
canvas = toyplot.Canvas(300, 300)
axes = canvas.axes(xlabel="Distance", ylabel="Count")
axes.barplot(numpy.histogram(scipy.spatial.distance.pdist(features, metric="euclidean")))
# Out:
# <div align="center" class="toyplot" id="tadcc2fd879ce4b75b61c45da1e72b602"><svg height="300px" id="t2f2213834052472290ff52e1ec2c4063" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="ta75e233a7e95449aaf9b2bc5212e5c71"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 60.0, "min": 0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 44.299975967947859, "min": 0.0}}]}</toyplot:axes><clipPath id="t0d6f79e31e81462494387a6ca30a75c3"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t0d6f79e31e81462494387a6ca30a75c3)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-VBarsMark" id="t9b11a02f45eb4dc29c491fa9fa8af58a" style="stroke:none;"><rect height="45.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="14.243200301" x="65.5207963129" y="195.0"></rect><rect height="33.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="14.243200301" x="83.3247966891" y="207.0"></rect><rect height="30.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="14.243200301" x="101.128797065" y="210.0"></rect><rect height="54.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="14.243200301" x="118.932797442" y="186.0"></rect><rect height="30.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="14.243200301" x="136.736797818" y="210.0"></rect><rect height="36.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="14.243200301" x="154.540798194" y="204.0"></rect><rect height="54.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="14.243200301" x="172.34479857" y="186.0"></rect><rect height="57.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="14.243200301" x="190.148798947" y="183.0"></rect><rect height="57.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="14.243200301" x="207.952799323" y="183.0"></rect><rect height="174.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="14.243200301" x="225.756799699" y="66.0"></rect></g></g><g class="toyplot-coordinates" style="visibility:hidden;"><rect height="14" style="opacity:0.75;stroke:none;fill:white;" width="90" x="150" y="60"></rect><text style="font-size:10px;font-weight:normal;stroke:none;text-anchor:middle;alignment-baseline:middle;" x="195.0" y="67.0"></text></g><line style="" x1="65.5207963129" x2="240.0" y1="250" y2="250"></line><g><text style="font-size:10px;baseline-shift:-80%;alignment-baseline:middle;font-weight:normal;stroke:none;text-anchor:middle;" x="60.0" y="250">0</text><text style="font-size:10px;baseline-shift:-80%;alignment-baseline:middle;font-weight:normal;stroke:none;text-anchor:middle;" x="100.632076218" y="250">10</text><text style="font-size:10px;baseline-shift:-80%;alignment-baseline:middle;font-weight:normal;stroke:none;text-anchor:middle;" x="141.264152437" y="250">20</text><text style="font-size:10px;baseline-shift:-80%;alignment-baseline:middle;font-weight:normal;stroke:none;text-anchor:middle;" x="181.896228655" y="250">30</text><text style="font-size:10px;baseline-shift:-80%;alignment-baseline:middle;font-weight:normal;stroke:none;text-anchor:middle;" x="222.528304873" y="250">40</text></g><text style="stroke:none;font-weight:bold;baseline-shift:-200%;text-anchor:middle;alignment-baseline:middle;" x="150.0" y="250">Distance</text><line style="" x1="50" x2="50" y1="66.0" y2="240.0"></line><g><text style="font-size:10px;baseline-shift:80%;alignment-baseline:middle;font-weight:normal;stroke:none;text-anchor:middle;" transf ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#tadcc2fd879ce4b75b61c45da1e72b602 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#tadcc2fd879ce4b75b61c45da1e72b602 text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     (function()
#     {
#       var root_id="tadcc2fd879ce4b75b61c45da1e72b602";
#
#       function sign(x)
#       {
#         if(x < 0)
#           return -1;
#         if(x > 0)
#           return 1;
#         return 0;
#       }
#
#       function log_n(x, base)
#       {
#         return Math.log(x) / Math.log(base);
#       }
#
#       function mix(a, b, amount)
#       {
#         return ((1.0 - amount) * a) + (amount * b);
#       }
#
#       // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#       function d3_mousePoint(container, e)
#       {
#         if (e.changedTouches) e = e.changedTouches[0];
#         var svg = container.ownerSVGElement || container;
#         if (svg.createSVGPoint) {
#           var point = svg.createSVGPoint();

# %%
import sklearn.cluster
kmeans = sklearn.cluster.KMeans(8)
kmeans.fit(features)
clusters = kmeans.predict(features)
cluster_order = numpy.argsort(clusters)
colormap = toyplot.color.CategoricalMap(toyplot.color.Palette())

# %%
canvas = toyplot.Canvas(1000, 1000)
axes = canvas.axes(xlabel="Time")
axes.y(show=False)
for index, (cluster, y) in enumerate(zip(clusters[cluster_order], timeseries[cluster_order])):
    axes.plot(t, (3 * index) + y, style={"stroke":colormap.css(cluster)})
# Out:
# <div align="center" class="toyplot" id="t48073907acfb4b1687d2751b25bb12d7"><svg height="1000px" id="t6c894b4b0d444b079e0a02927255357a" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="1000px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t861ecf8cc0cb43ba8b43fdd6397f56ad"><toyplot:axes>{"y": [{"range": {"max": 940, "min": 60}, "scale": "linear", "domain": {"max": 60.0, "min": -0.99999648208089331}}], "x": [{"range": {"max": 940, "min": 60}, "scale": "linear", "domain": {"max": 1.0, "min": 0.0}}]}</toyplot:axes><clipPath id="tb60404846fcb45c2855a0e3c859ee51d"><rect height="900" width="900" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tb60404846fcb45c2855a0e3c859ee51d)" style="cursor:crosshair;"><rect height="900" style="pointer-events:all;visibility:hidden;" width="900" x="50" y="50"></rect><polyline class="toyplot-PolyLineMark" id="tc6afa31fbba4490a9afb71554021dfff" points="60.0,932.623019603 60.8808808809,931.817966521 61.7617617618,930.988221304 62.6426426426,930.137065133 63.5235235235,929.26786386 64.4044044044,928.384054693 65.2852852853,927.489132608 66.1661661662,926.586636525 67.047047047,925.680135317 67.9279279279,924.773213692 68.8088088088,923.869458022 69.6896896897,922.972442161 70.5705705706,922.085713308 71.4514514515,921.212777984 72.3323323323,920.357088165 73.2132132132,919.522027629 74.0940940941,918.710898578 74.974974975,917.926908577 75.8558558559,917.173157872 76.7367367367,916.452627129 77.6176176176,915.768165647 78.4984984985,915.122480093 79.3793793794,914.518123794 80.2602602603,913.957486645 81.1411411411,913.442785654 82.022022022,912.976056178 82.9029029029,912.559143875 83.7837837838,912.1936974 84.6646646647,911.881161892 85.5455455455,911.622773256 86.4264264264,911.419553275 87.3073073073,911.272305572 88.1881881882,911.181612429 89.0690690691,911.147832489 89.9499499499,911.171099331 90.8308308308,911.251320948 91.7117117117,911.388180109 92.5925925926,911.58113561 93.4734734735,911.829424421 94.3543543544,912.132064696 95.2352352352,912.487859662 96.1161161161,912.895402346 96.996996997,913.353081143 97.8778778779,913.859086187 98.7587587588,914.411416509 99.6396396396,915.007887948 100.520520521,915.646141791 101.401401401,916.323654098 102.282282282,917.037745684 103.163163163,917.785592711 104.044044044,918.564237861 104.924924925,919.370602022 105.805805806,920.201496473 106.686686687,921.053635485 107.567567568,921.923649322 108.448448448,922.808097562 109.329329329,923.703482702 110.21021021,924.606263991 111.091091091,925.512871428 111.971971972,926.419719885 112.852852853,927.323223279 113.733733734,928.219808755 114.614614615,929.105930813 115.495495495,929.978085334 116.376376376,930.83282343 117.257257257,931.666765084 118.138138138,932.476612521 119.019019019,933.259163243 119.8998999,934.011322696 120.780780781,934.730116506 121.661661662,935.412702242 122.542542543,936.056380657 123.423423423,936.658606358 124.304304304,937.216997878 125.185185185,937.729347087 126.066066066,938.193627929 126.946946947,938.60800443 127.827827828,938.970837961 128.708708709,939.280693717 129.58958959,939.536346389 130.47047047,939.736785014 131.351351351,939.881216967 132.232232232,939.9690711 133.113113113,940.0 133.993993994,939.973881359 134.874874875,939.890818462 135.755755756,939.751139777 136.636636637,939.555397655 137.517517518,939.304366148 138.398398398,938.999037947 139.279279279,938.640620455 140.16016016,938.230531015 141.041041041,937.770391303 141.921921922,937.262020916 142.802802803,936.707430177 143.683683684,936.108812186 144.564564565,935.468534143 145.445445445,934.789127995 146.326326326,934.073280416 147.207207207,933.323822185 148.088088088,932.543716995 148.968968969,931.736049729 149.84984985,930.904014263 150.730730731,930.050900836 151.61 ...

# %% [markdown]
# # K-Means (Euclidean) Clustering on Time Domain Features

# %%
amplitudes = numpy.fft.fftshift(numpy.fft.fft(timeseries, axis=1)/n, axes=1)
frequencies = numpy.fft.fftshift(numpy.fft.fftfreq(n, 1/n))

#sin_features = (frequencies[numpy.argsort(numpy.abs(numpy.imag(amplitudes)), axis=1)])
#cos_features = (frequencies[numpy.argsort(numpy.abs(numpy.real(amplitudes)), axis=1)])

features = numpy.column_stack((numpy.real(amplitudes), numpy.imag(amplitudes)))

# %%
canvas = toyplot.Canvas(300, 300)
axes = canvas.axes(xlabel="Distance", ylabel="Count")
axes.barplot(numpy.histogram(scipy.spatial.distance.pdist(features, metric="euclidean")))
# Out:
# <div align="center" class="toyplot" id="tefed33d43f814b75bc89e4911a31d4ee"><svg height="300px" id="t70065e577ee8443dbb93681550b2bb09" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="300px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="t4b76bd7bdf814e0c8503a86cdc737a3e"><toyplot:axes>{"y": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 60.0, "min": 0}}], "x": [{"range": {"max": 240, "min": 60}, "scale": "linear", "domain": {"max": 1.5, "min": 0.0}}]}</toyplot:axes><clipPath id="tb869ccec314b4ba08fd84370e6578701"><rect height="200" width="200" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#tb869ccec314b4ba08fd84370e6578701)" style="cursor:crosshair;"><rect height="200" style="pointer-events:all;visibility:hidden;" width="200" x="50" y="50"></rect><g class="toyplot-VBarsMark" id="t1dae54b9eca745e48dfe509b33d9c114" style="stroke:none;"><rect height="45.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="13.3020879009" x="65.156012433" y="195.0"></rect><rect height="33.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="13.3020879009" x="81.7836223091" y="207.0"></rect><rect height="30.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="13.3020879009" x="98.4112321853" y="210.0"></rect><rect height="54.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="13.3020879009" x="115.038842061" y="186.0"></rect><rect height="30.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="13.3020879009" x="131.666451938" y="210.0"></rect><rect height="36.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="13.3020879009" x="148.294061814" y="204.0"></rect><rect height="54.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="13.3020879009" x="164.92167169" y="186.0"></rect><rect height="57.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="13.3020879009" x="181.549281566" y="183.0"></rect><rect height="57.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="13.3020879009" x="198.176891442" y="183.0"></rect><rect height="174.0" style="opacity:1.0;stroke:none;fill:rgba(40%,76.1%,64.7%,1);" width="13.3020879009" x="214.804501318" y="66.0"></rect></g></g><g class="toyplot-coordinates" style="visibility:hidden;"><rect height="14" style="opacity:0.75;stroke:none;fill:white;" width="90" x="150" y="60"></rect><text style="font-size:10px;font-weight:normal;stroke:none;text-anchor:middle;alignment-baseline:middle;" x="195.0" y="67.0"></text></g><line style="" x1="65.156012433" x2="228.106589219" y1="250" y2="250"></line><g><text style="font-size:10px;baseline-shift:-80%;alignment-baseline:middle;font-weight:normal;stroke:none;text-anchor:middle;" x="60.0" y="250">0.0</text><text style="font-size:10px;baseline-shift:-80%;alignment-baseline:middle;font-weight:normal;stroke:none;text-anchor:middle;" x="120.0" y="250">0.5</text><text style="font-size:10px;baseline-shift:-80%;alignment-baseline:middle;font-weight:normal;stroke:none;text-anchor:middle;" x="180.0" y="250">1.0</text><text style="font-size:10px;baseline-shift:-80%;alignment-baseline:middle;font-weight:normal;stroke:none;text-anchor:middle;" x="240.0" y="250">1.5</text></g><text style="stroke:none;font-weight:bold;baseline-shift:-200%;text-anchor:middle;alignment-baseline:middle;" x="150.0" y="250">Distance</text><line style="" x1="50" x2="50" y1="66.0" y2="240.0"></line><g><text style="font-size:10px;baseline-shift:80%;alignment-baseline:middle;font-weight:normal;stroke:none;text-anchor:middle;" transform="rotate(-90, 50, 240.0)" x="50" y="240.0">0</text><text style="font-size:10px;baseline-shift:80%;alignment-baseline:middle;font-weight:normal;stroke:none;text-anchor:middle;"  ...
#     (function()
#     {
#       // Workaround for browsers that don't support alignment-baseline
#       if(window.CSS !== undefined && window.CSS.supports !== undefined)
#       {
#         if(!window.CSS.supports("alignment-baseline", "middle"))
#         {
#           var re = /\s*alignment-baseline\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#tefed33d43f814b75bc89e4911a31d4ee text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               if(match[1] == "middle")
#               {
#                 var style = getComputedStyle(text[i]);
#                 var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#                 var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#                 dy += 0.4 * font_size;
#                 text[i].setAttribute("dy", dy);
#               }
#             }
#           }
#         }
#         if(!window.CSS.supports("baseline-shift", "0"))
#         {
#           var re = /\s*baseline-shift\s*:\s*([^;\s]*)\s*/;
#           var text = document.querySelectorAll("#tefed33d43f814b75bc89e4911a31d4ee text");
#           for(var i = 0; i != text.length; ++i)
#           {
#             var match = re.exec(text[i].attributes.style.value);
#             if(match)
#             {
#               var style = getComputedStyle(text[i]);
#               var font_size = style.fontSize.substr(0, style.fontSize.length - 2);
#               var percent = 0.01 * match[1].substr(0, match[1].length-1);
#               var dy = text[i].dy.baseVal.length ? text[i].dy.baseVal[0].value : 0;
#               dy -= percent * font_size
#               text[i].setAttribute("dy", dy);
#             }
#           }
#         }
#       }
#     })();
#     </script><script>
#     (function()
#     {
#       var root_id="tefed33d43f814b75bc89e4911a31d4ee";
#
#       function sign(x)
#       {
#         if(x < 0)
#           return -1;
#         if(x > 0)
#           return 1;
#         return 0;
#       }
#
#       function log_n(x, base)
#       {
#         return Math.log(x) / Math.log(base);
#       }
#
#       function mix(a, b, amount)
#       {
#         return ((1.0 - amount) * a) + (amount * b);
#       }
#
#       // Compute mouse coordinates relative to a DOM object, with thanks to d3js.org, where this code originated.
#       function d3_mousePoint(container, e)
#       {
#         if (e.changedTouches) e = e.changedTouches[0];
#         var svg = container.ownerSVGElement || container;
#         if (svg.createSVGPoint) {
#           var point = svg.createSVGPoint();
#           point.x = e.clientX, point.y = e.clientY;
#           point = point.matrixTransform(container.getScreenCTM().inverse());
#           return [point.x, point.y];
#         }
#         v

# %%
import sklearn.cluster
kmeans = sklearn.cluster.KMeans(4)
kmeans.fit(features)
clusters = kmeans.predict(features)
cluster_order = numpy.argsort(clusters)
colormap = toyplot.color.CategoricalMap(toyplot.color.Palette())

# %%
canvas = toyplot.Canvas(1000, 1000)
axes = canvas.axes(xlabel="Time")
axes.y(show=False)
for index, (cluster, y) in enumerate(zip(clusters[cluster_order], timeseries[cluster_order])):
    axes.plot(t, (3 * index) + y, style={"stroke":colormap.css(cluster)})
# Out:
# <div align="center" class="toyplot" id="td71ee67d1b934d929d07d003a8f1ce54"><svg height="1000px" id="tc2ac4bcfdb3f44fe86a5bac4e62c0342" style="opacity:1.0;font-size:12px;font-family:helvetica;stroke-opacity:1.0;fill-opacity:1.0;stroke:#343434;stroke-width:1.0;background-color:transparent;fill:#343434;" width="1000px" xmlns="http://www.w3.org/2000/svg" xmlns:toyplot="http://www.sandia.gov/toyplot"><g class="toyplot-Axes2D" id="tda6ec1985f4a4156ae27f40b675030d4"><toyplot:axes>{"y": [{"range": {"max": 940, "min": 60}, "scale": "linear", "domain": {"max": 60.0, "min": -0.99999746559111991}}], "x": [{"range": {"max": 940, "min": 60}, "scale": "linear", "domain": {"max": 1.0, "min": 0.0}}]}</toyplot:axes><clipPath id="t88b03e56010a402fb2a86cf2a9239afc"><rect height="900" width="900" x="50" y="50"></rect></clipPath><g class="toyplot-coordinate-events" clip-path="url(#t88b03e56010a402fb2a86cf2a9239afc)" style="cursor:crosshair;"><rect height="900" style="pointer-events:all;visibility:hidden;" width="900" x="50" y="50"></rect><polyline class="toyplot-PolyLineMark" id="tabe4cee221ad4b5b8a3ee2e41e18f0c7" points="60.0,924.250240017 60.8808808809,925.155768715 61.7617617618,926.06295052 62.6426426426,926.968198031 63.5235235235,927.867931497 64.4044044044,928.75859297 65.2852852853,929.636660379 66.1661661662,930.498661454 67.047047047,931.341187457 67.9279279279,932.160906668 68.8088088088,932.954577549 69.6896896897,933.719061574 70.5705705706,934.451335631 71.4514514515,935.148503983 72.3323323323,935.807809716 73.2132132132,936.426645641 74.0940940941,937.002564605 74.974974975,937.533289168 75.8558558559,938.016720609 76.7367367367,938.450947224 77.6176176176,938.834251888 78.4984984985,939.165118844 79.3793793794,939.442239695 80.2602602603,939.664518584 81.1411411411,939.831076519 82.022022022,939.941254858 82.9029029029,939.994617905 83.7837837838,939.990954639 84.6646646647,939.930279547 85.5455455455,939.812832565 86.4264264264,939.639078131 87.3073073073,939.409703346 88.1881881882,939.125615262 89.0690690691,938.787937288 89.9499499499,938.398004755 90.8308308308,937.957359628 91.7117117117,937.467744416 92.5925925926,936.931095274 93.4734734735,936.349534354 94.3543543544,935.725361404 95.2352352352,935.061044684 96.1161161161,934.359211198 96.996996997,933.622636307 97.8778778779,932.854232758 98.7587587588,932.05703916 99.6396396396,931.234207972 100.520520521,930.388993034 101.401401401,929.524736704 102.282282282,928.644856635 103.163163163,927.752832266 104.044044044,926.852191058 104.924924925,925.946494548 105.805805806,925.039324263 106.686686687,924.134267559 107.567567568,923.234903433 108.448448448,922.344788371 109.329329329,921.467442285 110.21021021,920.606334593 111.091091091,919.764870497 111.971971972,918.946377522 112.852852853,918.154092353 113.733733734,917.391148039 114.614614615,916.660561602 115.495495495,915.965222105 116.376376376,915.307879231 117.257257257,914.691132407 118.138138138,914.117420524 119.019019019,913.589012295 119.8998999,913.10799728 120.780780781,912.676277629 121.661661662,912.295560552 122.542542543,911.967351574 123.423423423,911.692948581 124.304304304,911.473436683 125.185185185,911.309683928 126.066066066,911.202337869 126.946946947,911.151822998 127.827827828,911.158339075 128.708708709,911.221860331 129.58958959,911.342135576 130.47047047,911.518689188 131.351351351,911.750822994 132.232232232,912.037619035 133.113113113,912.377943191 133.993993994,912.770449669 134.874874875,913.213586323 135.755755756,913.705600794 136.636636637,914.244547437 137.517517518,914.828295017 138.398398398,915.454535137 139.279279279,916.120791363 140.16016016,916.824429021 141.041041041,917.562665616 141.921921922,918.332581831 142.802802803,919.131133073 143.683683684,919.955161516 144.564564565,920.801408585 145.445445445,921.66652784 146.326326326,922.547098216 147.207207207,923.439637544 148.088088088,924.340616327 148.968968969,925.246471693 149.84984985,926.153621486 150.730730731,927.05847 ...
